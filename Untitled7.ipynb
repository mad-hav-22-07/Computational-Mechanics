# %% [markdown]
# <a href="https://colab.research.google.com/github/mad-hav-22-07/Computational-Mechanics/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
y1num = sp.lambdify(theta, y1a, 'numpy')
y2num = sp.lambdify(theta, y2a, 'numpy')
v1num = sp.lambdify(theta, v1a, 'numpy')
v2num = sp.lambdify(theta, v2a, 'numpy')

thetavec = np.linspace(0, 2*np.pi, 500)
yvec = np.zeros_like(thetavec)
vvec = np.zeros_like(thetavec)

for count in np.arange(500):
    if thetavec[count]< 1.6:
        yvec[count] = y1num(thetavec[count])
        vvec[count] = v1num(thetavec[count])
    elif (1.6) <= thetavec[count] and thetavec[count] <= 2.0:
        yvec[count] = Lnum
        vvec[count] = 0
    elif thetavec[count] > 2.0 and thetavec[count] < 3.5:
        yvec[count] = y2num(thetavec[count])
        vvec[count] = v2num(thetavec[count])
